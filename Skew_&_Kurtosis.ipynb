# %%
import numpy as np
from scipy.stats import skew, kurtosis
import pandas as pd
data=pd.read_csv('9.csv.csv')
data
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
speed = np.array([4, 4, 7, 7, 8, 9, 10, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17, 17, 17, 18, 18, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 22, 23, 24, 24, 24, 24, 25])
distance = np.array([2, 10, 4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34, 34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76, 84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 120, 85])

# %%
mean_speed = np.mean(speed)
median_speed = np.median(speed)
std_dev_speed = np.std(speed)

mean_distance = np.mean(distance)
median_distance = np.median(distance)
std_dev_distance = np.std(distance)

# %%
fourth_moment_speed = np.mean((speed - mean_speed)**4)
fourth_moment_distance = np.mean((distance - mean_distance)**4)

# %%
skewness_speed = skew(speed)
skewness_distance = skew(distance)

# %%
kurtosis_speed = kurtosis(speed)
kurtosis_distance = kurtosis(distance)

# %%
print("Skewness:", skewness_speed)
print("Kurtosis:", kurtosis_speed)
print
# Out:
# Skewness: -0.11395477012828319
# Kurtosis: -0.5771474239437371
# <function print>

# %%
print("Skewness:", skewness_distance)
print("Kurtosis:", kurtosis_distance)
print
# Out:
# Skewness: 0.7824835173114966
# Kurtosis: 0.24801865717051808
# <function print>
